# %% [markdown]
# ## __Estrutura da Page em html__

# %% [markdown]
# ##### Inicio de documento

# %%
<!DOCTYPE html>
<html lang="en">

# %% [markdown]
# #### Aba do navegador

# %%
<head>
    <meta charset="UTF-8">
    <meta http-equiv="X-UA-Compatible" content="IE-edge">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Personal Portfolio</title>

    <!--Favicon - pequeno icone na aba do navegador-->

    <link rel="shortcut icon" href="./assets/images/avatar1.png" type="image/x-icon">
    <!----------------------------------------------------------------------------------------------->


    <!--Folha do CSS-->

    <link rel="stylesheet" href="./assets/css/style.css">
    <!----------------------------------------------------------------------------------------------->

    <!--Links google para melhorar carregamento da página-->

    <link rel="preconnect" href="https://fonts.googleapis.com">
    <link rel="preconnect" href="http://fonts.gstatic.com" crossorigin>
    <link rel="https://fonts.googleapis.com/css2?family=Poppins:wght@300;400;500;600&display=swap" rel="stylesheet">
    <!----------------------------------------------------------------------------------------------->
</head>

# %% [markdown]
# #### Inicio do layout da Page

# %%
<body>
    <main>
       <!------------------------------------- #SIDEAR - BARRA LATERAL ESQUERDA---------------------------------------------------------------------> 

       <aside class="sidebar" data-sidebar>
           <!--Informações superiores da barra lateral-->  

            <div class="sidebar-info">

                <!--Figura-->
                <figure class="avatar-box">
                    <img src="./assets/images/avatar1.png" alt="Danyelle Melo" width="80">
                </figure>

                <!--Nome e funçao-->
                <div class="info-content">
                    <h1 class="name" title="Danyelle Melo">Danyelle Melo</h1>
                    <p class="title">Data Analyst</p>
                </div>

                <!--Botão para exibir o sidbar em dispositivos móveis-->
                <button class="info_more-btn" data-sidebar-btn> <!--botão de mais informações-->
                    <span>Show Contacts</span> <!--essa tag <span> é utilizada para lista suspensa-->
                    <ion-icon name="chevron-down"></ion-icon> <!--essa tag <ion-icon> é utilizada para exibir icone de seta para baixo-->
                </button>
            </div>
            <!-------------------------------------------------------------------------------------------------------------------------------->

            <!--mais informações-->
            <div class="sidebar-info_more"> 
                <!--separador-->
                <div class="separator"></div> <!--linha para separar o (sidebar-info/sidear-info_more) com stilo definido no css-->

                <!--icones de informações pessoais-->

                <!--Lista contatos-->
                <ul class="contacts-list">

                    <!--icone de e-mail-->
                    <li class="contact-item"> 

                        <!--icone-->
                        <div class="icon-box">
                            <ion-icon class="mail-outline"></ion-icon>
                        </div>

                        <!--informação do icone-->
                        <div class="contact-info">
                            <p class="contact-title">Email</p>

                            <a href="mailto:danyelle.dados@gmail.com" class="contacts-link">danyelle.dados@gmail.com</a>
                        </div>
                    </li> 
                    <!--------------------------------------------------------------------------------------------------------------->

                    <!--icone do telefone-->
                    <li class="contact-item"> 

                        <!--icone-->
                        <div class="icon-box">
                            <ion-icon class="phone-portrait-outline"></ion-icon>
                        </div>

                        <!--informação do icone-->
                        <div class="contact-info">
                            <p class="contact-title">Phone</p>

                            <a href="tel:+5581997909873" class="contacts-link">+55 (81) 99790-9873</a>
                        </div>
                    </li>
                    <!--------------------------------------------------------------------------------------------------------------->

                    <!--icone data nascimento-->
                    <li class="contact-item"> 

                        <!--icone-->
                        <div class="icon-box">
                            <ion-icon class="calendar-outline"></ion-icon>
                        </div>

                        <!--informação do icone-->
                        <div class="contact-info">
                            <p class="contact-title">Birthday</p>

                            <time datetime="1993-04-17">April 17, 1993</time>
                        </div>
                    </li>
                    <!--------------------------------------------------------------------------------------------------------------->

                    <!--icone localização-->
                    <li class="contact-item"> 

                        <!--icone-->
                        <div class="icon-box">
                            <ion-icon class="location-outline"></ion-icon>
                        </div>

                        <!--informação do icone-->
                        <div class="contact-info">
                            <p class="contact-title">Location</p>

                           <address>Jaboatão dos Guararapes, Pernambuco - Brazil</address>
                        </div>
                    </li>
                </ul>
                <!--------------------------------------------------------------------------------------------------------------->

                <div class="separator"></div> <!-- linha parar separar os icones de contatos/ linkedin e github-->
                <!--------------------------------------------------------------------------------------------------------------->

                <ul class="social-list">
                    <!--icone linkedin-->
                    <li class="social-item">
                        <a href="https://www.linkedin.com/in/danyellemelo" class="social-link">
                            <ion-icon name="logo-linkedin"></ion-icon>
                        </a>
                    </li>

                    <!--icone github-->
                    <li class="social-item">
                        <a href="https://github.com/data-ny" class="social-link">
                            <ion-icon name="logo-github"></ion-icon>
                        </a>
                    </li>
                </ul>
            </div>
        </aside>

       <!--///////////////////////////////////////////// FIM DA BARRA LATERAL //////////////////////////////////////////////-->

       <!-------------------------------------Inicio do conteudo principal - #main-content ----------------------------------------------------------> 

        <div class="main-content">

            <!----------------------------------------#NAVBAR - MENU--------------------------->
            <nav class="navbar">
                <ul class="navbar-list">

                    <!--botão About-->
                    <li class="navbar-item">
                        <button class="navbar-link active" data-sidebar-link> About</button>
                    </li>

                    <!--botão Resume-->
                    <li class="navbar-item">
                        <button class="navbar-link active" data-sidebar-link>Resume</button>
                    </li>

                    <!--botão Projetos-->
                    <li class="navbar-item">
                        <button class="navbar-link" data-sidebar-link>Portifolio</button>
                    </li>

                    <!--botão Blog-->
                    <li class="navbar-item">
                        <button class="navbar-link active" data-sidebar-link>Blog</button>
                    </li>

                    <!--botão Contact-->
                    <li class="navbar-item">
                        <button class="navbar-link active" data-sidebar-link>Contact</button>
                    </li>
                </ul>
            </nav>

            <!-------------------------------------FIM DO MENU-------------------------------------------------------------------------->

            <!--------------------------------INFORMAÇÕES DO MENU------------------------------------------------->

            <!--****** ABOUT *****-->
            <article class="about active" data-page="about"> <!--toda página se inicia com um <article></article>-->
               
                <!--titulo da pagina About-->
                <head>
                    <h2 class="h2 article-title">About Me</h2>
                </head>

                <!--texto sobre você-->
                <section class="about-text">
                    <p>
                        My name is Danyelle Melo and I am a Data Technician with experience in data analysis, BI, 
                        data extraction, automation and workflow management. 
                        I am passionate about transforming raw data into actionable insights that drive business success. 
                    </p>

                    <p>
                        I am a dedicated, proactive professional with a great capacity for learning. 
                        I have excellent communication and teamwork skills. I always look for new challenges and 
                        opportunities to develop my skills and contribute to the company's growth.  
                    </p>
                    <p>
                        If you are looking for an experienced Data Technician who is passionate about what she does, contact me! 
                    </p>

                </section>

                <!-- service -->

                <section class="service">

                    <!-- segundo titulo da página-->
                    <h3 class="h3 service-title">what i'm doing</h3>

                    <!-- LISTA dos meus sprojetos em processo -->
                    <ul class="service-list has-scrollbar">

                        <li class="service-item">

                            <!-- icone do primeiro projeto -->
                            <div class="service-icon-box">
                                <img src="./assets/images/projeto-placa-icon.png" alt="design icon" width="40">
                            </div>

                            <!-- caixa com o titulo e descrição -->
                            <div class="service-content-box">
                                <h4 class="service-item-title">Board Design</h4>

                                <P class="service-item-text">
                                 The Placa Project aims to develop a complete system for the detection and recognition of passenger car license plates in condominiums, automating the entry and access authorization process.
                                </P>
                            </div>

                        </li>

                    </ul>
                </section>

                <!-- testimonials -->
                <section class="Testimonials">
                    <!-- terceiro título - testemunhas -->
                    <h3 class="h3 testimonials-title">Testimonials</h3>

                    <!-- lista de testemunhas com uma barra de rolagem -->
                    <ul class="testimonials-list has-scrollbar">
                        <!-- item da lista -->
                        <li class="testimonials-item">

                            <div class="content-card" data-testimonials-item>
                                <!-- figura da testemunha -->
                                <figure class="testimonials-avatar-box">
                                    <img src="#" alt="Daniel lewis" width="60" data-testimonials-avatar>
                                </figure>

                                <!-- nome da testemunha -->
                                <h4 class="h4 testimonials-item-title" data-testimonials-title>Amanda Silva</h4>

                                <!-- comentário da testemunha -->
                                <div class="testimonials-text" data-testimonials-text>
                                    <p>
                                        Danyelle is very creative in her projects. I always expect something more than planned. We created a database on beverage storage and dispatch and I was surprised by a panel to facilitate understanding. 
                                    </p>
                                </div>
                            </div>
                        </li>
                    </ul>
                </section>
            </article>
            <!---------------------------------------------------------FIM DO ABOUT ----------------------------------------------------------------->

            <!-------------------------------------- INICIO DO RESUME ------------------------------------------------------------------------------->

            <article class="resume" data-page="resume">
                <!-- titulo da pagina resumo -->
                <header>
                    <h2 class="h2 article-title">Resume</h2>
                </header>

                <!-- linha do tempo da formação -->
                <section class="timeline">

                    <!-- icone do livro -->
                    <div class="title-wrapper">
                        <div class="icon-box">
                            <ion-icon name="book-outline"></ion-icon>
                        </div>
                        
                        <!-- titulo do icone ao lado -->
                        <h3 class="h3">Education</h3>
                    </div>

                    <ol class="timeline-list">

                        <!-- segunda formação -->
                        <li class="timeline-item">

                            <h4 class="h4 timeline-item-title">Cruzeiro do Sul Virtual</h4>
                            <span>2021 - 2023</span>

                            <p class="timeline-text">
                                Postgraduate Lato Sensu - Specialization, Database and business intelligence.
                            </p>

                        </li>
                        <!-- primeira formação -->
                        <li class="timeline-item">

                            <h4 class="h4 timeline-item-title">Universidade Federal Rural de Pernambuco</h4>
              
                            <span>2014 — 2019</span>
              
                            <p class="timeline-text">
                              Bachelor's degree, business administration. 
                            </p>
              
                          </li>
                    </ol>
                </section>


                <!-- linha do tempo das experiências -->
                <section class="timeline">

                    <!-- icone do livro -->
                    <div class="title-wrapper">
                        <div class="icon-box">
                            <ion-icon name="book-outline"></ion-icon>
                        </div>
                        
                        <!-- titulo do icone ao lado -->
                        <h3 class="h3">Experience</h3>
                    </div>

                    <ol class="timeline-list">

                        <!-- ultima experiencia -->
                        <li class="timeline-item">

                            <h4 class="h4 timeline-item-title">Data technician</h4>
                            <span>2022 — Present</span>

                            <p class="timeline-text">
                                G4F - Great 4 the Future, Client CHESF.
                            </p>

                        </li>
                        <!-- primeira experiencia -->
                        <li class="timeline-item">

                            <h4 class="h4 timeline-item-title">Invoicing</h4>
              
                            <span>2015 — 2022</span>
              
                            <p class="timeline-text">
                                Solivetti Comercio e Serviços LTDA.
                            </p>
              
                          </li>
                    </ol>
                </section>


                <!-- section Skills -->
                <section class="skill">
                    <h3 class="h3 skills-title">My Skills</h3>

                    <ul class="skills-list content-card">
                        <!-- PONTO 1 -->
                        <li class="skills-item">
                            <div class="title-wrapper">
                                <h5 class="h5">Data analysis</h5>
                                <p> 
                                    <span class="bullet-point">&#9679;</span>BI,data extraction with VBA and Python from SAP PM, selects in PostgreSQL, creation of dashboards and reports.
                                </p> 
                            </div>
                        </li>
                        <!-- PONTO 2 -->
                        <li class="skills-item">
                            <div class="title-wrapper">
                              <h5 class="h5">Automation</h5>
                                <p> 
                                  <span class="bullet-point">&#9679;</span>Creating scripts in Python to automate repetitive tasks.
                                </p>  
                            </div>          
                        </li>
                        <!-- PONTO 3 -->
                        <li class="skills-item">
                            <div class="title-wrapper">
                              <h5 class="h5">Workflow management</h5>
                                <p>
                                    <span class="bullet-point">&#9679;</span> Creating and managing workflows in Airflow.
                                </p>
                            </div>
                        </li>
                        <!-- PONTO 4 -->
                        <li class="skills-item">
                            <div class="title-wrapper">
                              <h5 class="h5">Proficiency in tools</h5>
                                <p>
                                    <span class="bullet-point">&#9679;</span> SQL, Python, VBA, SAP PM, PostgreSQL, Airflow, Tableau, Power BI.
                                </p>
                            </div>
                        </li>
                    </ul>
                </section>
            </article>

            <!-------------------------FIM DO RESUMO ------------------------------------------------------------------------------------->

            <!--------------------------------------------INICIO DO PORTIFOLIO ----------------------------------------------------------->
        </div>

    
    </main>
</body>
